# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from math import sqrt

# %%
df= pd.read_csv("C:/Users/Administrator/Downloads/historic_demand_2009_2024_noNaN.csv")
df
# Out:
#             settlement_date  settlement_period period_hour     nd    tsd  \
# 0       2009-01-01 00:00:00                  1     0:00:00  37910  38704
# 1       2009-01-01 00:30:00                  2     0:30:00  38047  38964
# 2       2009-01-01 01:00:00                  3     1:00:00  37380  38651
# 3       2009-01-01 01:30:00                  4     1:30:00  36426  37775
# 4       2009-01-01 02:00:00                  5     2:00:00  35687  37298
# ...                     ...                ...         ...    ...    ...
# 278507  2024-12-05 21:30:00                 44    21:30:00  29114  31431
# 278508  2024-12-05 22:00:00                 45    22:00:00  27204  29846
# 278509  2024-12-05 22:30:00                 46    22:30:00  26006  28805
# 278510  2024-12-05 23:00:00                 47    23:00:00  23908  26825
# 278511  2024-12-05 23:30:00                 48    23:30:00  23217  26133
#
#         england_wales_demand  embedded_wind_generation  \
# 0                      33939                        54
# 1                      34072                        53
# 2                      33615                        53
# 3                      32526                        50
# 4                      31877                        50
# ...                      ...                       ...
# 278507                 27212                      5377
# 278508                 25477                      5486
# 278509                 24428                      5594
# 278510                 22590                      5575
# 278511                 21958                      5556
#
#         embedded_wind_capacity  embedded_solar_generation  \
# 0                         1403                          0
# 1                         1403                          0
# 2                         1403                          0
# 3                         1403                          0
# 4                         1403                          0
# ...                        ...                        ...
# 278507                    6622                          0
# 278508                    6622                          0
# 278509                    6622                          0
# 278510                    6622                          0
# 278511                    6622                          0
#
#         embedded_solar_capacity  non_bm_stor  pump_storage_pumping  ifa_flow  \
# 0                             0            0                    33      2002
# 1                             0            0                   157      2002
# 2                             0            0                   511      2002
# 3                             0            0                   589      1772
# 4                             0            0                   851      1753
# ...                         ...          ...                   ...       ...
# 278507                    17194            0                   736       558
# 278508                    17194            0                   868      -193
# 278509                    17194            0                   944      -274
# 278510                    17194            0                   864      -404
# 278511                    17194            0                   820      -415
#
#         ifa2_flow  britned_flow  moyle_flow  east_west_flow  nemo_flow  \
# 0               0             0        -161               0          0
# 1               0             0        -160               0          0
# 2               0             0        -160               0          0
# 3               0             0        -160               0          0
# 4               0             0        -160               0          0
# ...           ...           ...         ...             ...        ...
# 278507        758          1003        -450            -531        999
# 278508        263          1002        -450            -531        949
# 278509        211           997        -450            -531        943
# 278510        -77           280        -450            -522        338
# 278511       -101           218        -450            -530        292
#
#         is_holiday
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 278507           0
# 278508           0
# 278509           0
# 278510           0
# 278511           0
#
# [278512 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278512 entries, 0 to 278511
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   settlement_date            278512 non-null  object
#  1   settlement_period          278512 non-null  int64
#  2   period_hour                278512 non-null  object
#  3   nd                         278512 non-null  int64
#  4   tsd                        278512 non-null  int64
#  5   england_wales_demand       278512 non-null  int64
#  6   embedded_wind_generation   278512 non-null  int64
#  7   embedded_wind_capacity     278512 non-null  int64
#  8   embedded_solar_generation  278512 non-null  int64
#  9   embedded_solar_capacity    278512 non-null  int64
#  10  non_bm_stor                278512 non-null  int64
#  11  pump_storage_pumping       278512 non-null  int64
#  12  ifa_flow                   278512 non-null  int64
#  13  ifa2_flow                  278512 non-null  int64
#  14  britned_flow               278512 non-null  int64
#  15  moyle_flow                 278512 non-null  int64
#  16  east_west_flow             278512 non-null  int64
#  17  nemo_flow                  278512 non-null  int64
#  18  is_holiday                 278512 non-null  int64
# dtypes: int64(17), object(2)
# memory usage: 40.4+ MB

# %%
df.describe()
# Out:
#        settlement_period             nd            tsd  england_wales_demand  \
# count      278512.000000  278512.000000  278512.000000         278512.000000
# mean           24.497357   31187.041370   32685.811143          28389.589217
# std            13.852025    7831.306542    7598.781279           7091.113104
# min             1.000000   13367.000000   16513.000000              0.000000
# 25%            12.000000   24907.750000   26608.000000          22676.750000
# 50%            24.000000   30491.000000   31800.000000          27753.000000
# 75%            36.000000   36914.000000   38112.000000          33616.000000
# max            48.000000   59095.000000   60147.000000          53325.000000
#
#        embedded_wind_generation  embedded_wind_capacity  \
# count             278512.000000           278512.000000
# mean                1272.085027             4453.970263
# std                  966.548452             1955.825654
# min                    0.000000             1403.000000
# 25%                  552.000000             2109.000000
# 50%                 1018.000000             4831.000000
# 75%                 1729.000000             6527.000000
# max                 5930.000000             6622.000000
#
#        embedded_solar_generation  embedded_solar_capacity    non_bm_stor  \
# count              278512.000000            278512.000000  278512.000000
# mean                  880.245314              8705.061549       6.668416
# std                  1710.954426              5869.536138      39.197650
# min                     0.000000                 0.000000     -24.000000
# 25%                     0.000000              2046.000000       0.000000
# 50%                     0.000000             11503.000000       0.000000
# 75%                   889.000000             13080.000000       0.000000
# max                 11224.000000             17197.000000     893.000000
#
#        pump_storage_pumping       ifa_flow      ifa2_flow   britned_flow  \
# count         278512.000000  278512.000000  278512.000000  278512.000000
# mean             304.497031     926.247609      53.998768     504.137998
# std              528.163447    1068.846762     354.179475     541.678428
# min                0.000000   -2056.000000   -1030.000000   -1215.000000
# 25%                8.000000     271.000000       0.000000       0.000000
# 50%               11.000000    1183.000000       0.000000     726.000000
# 75%              366.000000    1892.000000       0.000000     994.000000
# max             2019.000000    2066.000000    1016.000000    1143.000000
#
#           moyle_flow  east_west_flow      nemo_flow     is_holiday
# count  278512.000000   278512.000000  278512.000000  278512.000000
# mean     -125.145276      -51.106742     176.336876       0.022405
# std       230.383910      263.267266     422.130995       0.147996
# min      -505.000000     -585.000000   -1023.000000       0.000000
# 25%      -303.000000     -209.000000       0.000000       0.000000
# 50%      -148.000000        0.000000       0.000000       0.000000
# 75%        25.000000        0.000000     338.000000       0.000000
# max       499.000000      504.000000    1033.000000       1.000000

# %%
df['datetime'] = pd.to_datetime(df['settlement_date'] + ' ' + df['period_hour'])
df = df.set_index('datetime')
df = df.sort_index()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23820\2416516666.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['datetime'] = pd.to_datetime(df['settlement_date'] + ' ' + df['period_hour'])

# %%
print((df['settlement_date'].astype(str) + ' ' + df['period_hour'].astype(str)).head(10))
# Out:
# datetime
# 2009-01-01 00:00:00    2009-01-01 00:00:00 0:00:00
# 2009-01-01 00:30:00    2009-01-01 00:30:00 0:30:00
# 2009-01-01 01:00:00    2009-01-01 01:00:00 1:00:00
# 2009-01-01 01:30:00    2009-01-01 01:30:00 1:30:00
# 2009-01-01 02:00:00    2009-01-01 02:00:00 2:00:00
# 2009-01-01 02:30:00    2009-01-01 02:30:00 2:30:00
# 2009-01-01 03:00:00    2009-01-01 03:00:00 3:00:00
# 2009-01-01 03:30:00    2009-01-01 03:30:00 3:30:00
# 2009-01-01 04:00:00    2009-01-01 04:00:00 4:00:00
# 2009-01-01 04:30:00    2009-01-01 04:30:00 4:30:00
# dtype: object

# %%
# Visualize demand
plt.figure(figsize=(10,4))
plt.plot(df['nd'], label="National Demand (ND)", color="blue")
plt.xlabel("Time")
plt.ylabel("MW")
plt.title("Electricity Demand Over Time")
plt.legend()
plt.show()

# %%
# Demand distribution
plt.figure(figsize=(8,4))
sns.histplot(df['nd'], bins=50, kde=True)
plt.title('Distribution of National Demand')
plt.xlabel('Demand (MW)')
plt.show()

# %%
# Plot only 1 year
plt.figure(figsize=(10,4))
plt.plot(df.loc['2023':'2024', 'nd'], label="National Demand (ND)", color="blue")
plt.xlabel("Time")
plt.ylabel("MW")
plt.title("Electricity Demand for 1 Year")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.plot(df.loc['2024-08', 'nd'], label="july 2024 Demand", color="blue")
plt.xlabel("Time")
plt.ylabel("MW")
plt.title("Electricity Demand for july 2024")
plt.legend()
plt.show()

# %%
df['settlement_date'] = pd.to_datetime(df['settlement_date'])
df.set_index('settlement_date', inplace=True)

# %%
df = df[df.index <= '2024-11-30']
# Aggregate demand to monthly total
df_monthly = df['nd'].resample('M').sum()
df_monthly
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23820\1737477922.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly = df['nd'].resample('M').sum()
# settlement_date
# 2009-01-31    63238939
# 2009-02-28    56073378
# 2009-03-31    56519297
# 2009-04-30    49311414
# 2009-05-31    48437067
#                 ...
# 2024-07-31    33960607
# 2024-08-31    32288427
# 2024-09-30    35002964
# 2024-10-31    39733798
# 2024-11-30    42742427
# Freq: ME, Name: nd, Length: 191, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(df_monthly, label="Monthly Electricity Consumption", color="blue")
plt.xlabel("Year")
plt.ylabel("Electricity Demand (MWh)")
plt.title("Monthly Electricity Demand (2009-2025)")
plt.legend()
plt.show()

# %%
# Find months with maximum and minimum electricity demand
max_month = df_monthly.idxmax()
min_month = df_monthly.idxmin()

max_value = df_monthly.max()
min_value = df_monthly.min()

print(f"📈 Month with highest electricity consumption: {max_month} with {max_value:.2f} MW")
print(f"📉 Month with lowest electricity consumption: {min_month} with {min_value:.2f} MW")
# Out:
# 📈 Month with highest electricity consumption: 2010-12-31 00:00:00 with 65015253.00 MW
# 📉 Month with lowest electricity consumption: 2024-06-30 00:00:00 with 31828428.00 MW

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(df_monthly, label="Monthly Electricity Consumption", color="blue")
plt.axvline(x=max_month, color='red', linestyle='--', label="Max Consumption")
plt.axvline(x=min_month, color='green', linestyle='--', label="Min Consumption")
plt.xlabel("Year")
plt.ylabel("Electricity Demand (MWh)")
plt.title("Monthly Electricity Demand (2009-2025)")
plt.legend()
plt.show()

# %% [markdown]
# PART 1 ARIMA

# %%
from statsmodels.tsa.stattools import adfuller
# Perform ADF Test
adf_test = adfuller(df_monthly)

print(f"ADF Statistic: {adf_test[0]:.4f}")
print(f"p-value: {adf_test[1]:.4f}")

if adf_test[1] < 0.05:
    print("The data is stationary (reject null hypothesis).")
else:
    print("The data is NOT stationary (fail to reject null hypothesis).")
# Out:
# ADF Statistic: -0.5648
# p-value: 0.8787
# The data is NOT stationary (fail to reject null hypothesis).

# %%
df_diff = df_monthly.diff().dropna()

# Check stationarity again
from statsmodels.tsa.stattools import adfuller

adf_test = adfuller(df_diff)

print(f"ADF Statistic: {adf_test[0]:.4f}")
print(f"p-value: {adf_test[1]:.4f}")

if adf_test[1] < 0.05:
    print("The data is now stationary.")
else:
    print("The data is still NOT stationary. Try second-order differencing.")
# Out:
# ADF Statistic: -5.5171
# p-value: 0.0000
# The data is now stationary.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 1, figsize=(12, 8))

# ACF: Determines MA(q) order
plot_acf(df_monthly.diff().dropna(), ax=ax[0])
ax[0].set_title("Autocorrelation Function (ACF)")

# PACF: Determines AR(p) order
plot_pacf(df_monthly.diff().dropna(), ax=ax[1])
ax[1].set_title("Partial Autocorrelation Function (PACF)")

plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

train_size = int(len(df_monthly) * 0.8)  # Use 80% of data for training
train, test = df_monthly[:train_size], df_monthly[train_size:]

p, d, q = 12, 1, 12
model2 = ARIMA(train, order=(p, d, q))
model_fit = model2.fit()

# Forecast the test set
forecast = model_fit.forecast(steps=len(test))

# Convert forecast to pandas series for comparison
forecast_series = pd.Series(forecast, index=test.index)

# Plot the forecast vs actual values
plt.figure(figsize=(10, 6))
plt.plot(train, label='Training Data')
plt.plot(test, label='Test Data', color='red')
plt.plot(forecast_series, label='ARIMA Forecast', color='green')
plt.title('ARIMA Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# C:\Users\Administrator\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Administrator\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
predicted_vs_actual = pd.DataFrame({
    'Actual': test,
    'Predicted': forecast
})

predicted_vs_actual['Actual'] = predicted_vs_actual['Actual'].astype(int)
predicted_vs_actual['Predicted'] = predicted_vs_actual['Predicted'].astype(int)
predicted_vs_actual
# Out:
#               Actual  Predicted
# 2021-09-30  37446180   40831696
# 2021-10-31  40560727   44113124
# 2021-11-30  44898882   45929026
# 2021-12-31  47642643   46646996
# 2022-01-31  48750749   46225541
# 2022-02-28  40887505   43344182
# 2022-03-31  43485339   40905645
# 2022-04-30  37399615   37005972
# 2022-05-31  35482844   35890914
# 2022-06-30  32909402   34019246
# 2022-07-31  34644371   35844298
# 2022-08-31  34719352   37657271
# 2022-09-30  34708171   41391367
# 2022-10-31  36760075   44039472
# 2022-11-30  40300587   45973159
# 2022-12-31  46331575   46744197
# 2023-01-31  45692038   45737875
# 2023-02-28  39747240   43365696
# 2023-03-31  43182167   40167464
# 2023-04-30  36750722   36980378
# 2023-05-31  34141063   35456841
# 2023-06-30  32278512   34348000
# 2023-07-31  32493119   36214772
# 2023-08-31  33137003   38036772
# 2023-09-30  34278867   41753396
# 2023-10-31  37983453   43967797
# 2023-11-30  42746783   46312262
# 2023-12-31  43953301   46682811
# 2024-01-31  47331548   45472701
# 2024-02-29  41100306   42890191
# 2024-03-31  41462729   39611181
# 2024-04-30  36303781   37015737
# 2024-05-31  34403810   35196799
# 2024-06-30  31828428   34781339
# 2024-07-31  33960607   36277799
# 2024-08-31  32288427   38462530
# 2024-09-30  35002964   41979004
# 2024-10-31  39733798   44285895
# 2024-11-30  42742427   46586352

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = sqrt(mean_squared_error(y_true, y_pred))
    return mae, rmse

# Evaluate the model
mae, rmse = evaluate_model(test, forecast_series)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# Mean Absolute Error (MAE): 2951619.9673057636
# Root Mean Squared Error (RMSE): 3624612.9101834605

# %%
future_forecast = model_fit.forecast(steps=24)
future_dates = pd.date_range(start='2024-12-01', periods=24, freq='MS')  # 'MS' stands for Month Start

# Create a DataFrame with the future forecast values
future_forecast_df = pd.DataFrame({
    'Date': future_dates,
    'Forecasted Demand': future_forecast
})
future_forecast_df['Forecasted Demand'] = future_forecast_df['Forecasted Demand'].astype(int)

future_forecast_df
# Out:
#                  Date  Forecasted Demand
# 2021-09-30 2024-12-01           40831696
# 2021-10-31 2025-01-01           44113124
# 2021-11-30 2025-02-01           45929026
# 2021-12-31 2025-03-01           46646996
# 2022-01-31 2025-04-01           46225541
# 2022-02-28 2025-05-01           43344182
# 2022-03-31 2025-06-01           40905645
# 2022-04-30 2025-07-01           37005972
# 2022-05-31 2025-08-01           35890914
# 2022-06-30 2025-09-01           34019246
# 2022-07-31 2025-10-01           35844298
# 2022-08-31 2025-11-01           37657271
# 2022-09-30 2025-12-01           41391367
# 2022-10-31 2026-01-01           44039472
# 2022-11-30 2026-02-01           45973159
# 2022-12-31 2026-03-01           46744197
# 2023-01-31 2026-04-01           45737875
# 2023-02-28 2026-05-01           43365696
# 2023-03-31 2026-06-01           40167464
# 2023-04-30 2026-07-01           36980378
# 2023-05-31 2026-08-01           35456841
# 2023-06-30 2026-09-01           34348000
# 2023-07-31 2026-10-01           36214772
# 2023-08-31 2026-11-01           38036772

# %%
future_forecast_df.set_index('Date', inplace=True)
future_forecast_df['Forecasted Demand'] = future_forecast_df['Forecasted Demand'].astype(int)
plt.figure(figsize=(10, 6))
plt.plot(future_forecast_df.index, future_forecast_df['Forecasted Demand'], label='Future Forecast (Next 24 Months)', color='purple')
plt.title('Electricity Demand Forecast for the Next 24 Months')
plt.xlabel('Date')
plt.ylabel('Forecasted Demand')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_monthly
# Out:
# settlement_date
# 2009-01-31    63238939
# 2009-02-28    56073378
# 2009-03-31    56519297
# 2009-04-30    49311414
# 2009-05-31    48437067
#                 ...
# 2024-07-31    33960607
# 2024-08-31    32288427
# 2024-09-30    35002964
# 2024-10-31    39733798
# 2024-11-30    42742427
# Freq: ME, Name: nd, Length: 191, dtype: int64

# %%
data = df_monthly.copy()
data = data.to_frame()
data['settlement_date'] = data.index

data.reset_index(drop=True, inplace=True)
train_size = int(len(data) * 0.8)
train, test = data[:train_size], data[train_size:]
scaler = MinMaxScaler()
train['nd'] = scaler.fit_transform(train[['nd']])
test['nd'] = scaler.transform(test[['nd']])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23820\2822739239.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['nd'] = scaler.fit_transform(train[['nd']])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23820\2822739239.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['nd'] = scaler.transform(test[['nd']])

# %%
def create_sequences(data, seq_length):
    sequences, labels = [], []
    for i in range(len(data) - seq_length):
        sequences.append(data[i: i + seq_length])
        labels.append(data[i + seq_length])
    return np.array(sequences), np.array(labels)


seq_length = 24 
X_train, y_train = create_sequences(train['nd'].values, seq_length)
X_test, y_test = create_sequences(test['nd'].values, seq_length)


X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1)) # Reshaping the data for RNN/LSTM
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# RNN MODEL

# %%
rnn_model = Sequential([
    SimpleRNN(100, activation='tanh', return_sequences=True, input_shape=(seq_length, 1)),
    Dropout(0.3),
    SimpleRNN(100, activation='tanh'),
    Dropout(0.3),
    Dense(1)
])
rnn_model.compile(optimizer=Adam(learning_rate=0.0005), loss='mse')  # Using MSE for RNN model
rnn_history = rnn_model.fit(X_train, y_train, epochs=100, batch_size=4, verbose=1, validation_data=(X_test, y_test))
# Out:
# C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - loss: 0.2379 - val_loss: 0.0781
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1471 - val_loss: 0.0055
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1208 - val_loss: 0.0484
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0999 - val_loss: 0.0160
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0932 - val_loss: 0.0147
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0640 - val_loss: 0.0070
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0643 - val_loss: 0.0112
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0622 - val_loss: 0.0063
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0501 - val_loss: 0.0087
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0503 - val_loss: 0.0020
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0338 - val_loss: 0.0040
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0427 - val_loss: 0.0035
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0269 - val_loss: 0.0029
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0253 - val_loss: 0.0042
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0294 - val_loss: 0.0045
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0318 - val_loss: 0.0033
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0235 - val_loss: 0.0025
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0292 - val_loss: 0.0028
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0237 - val_loss: 0.0035
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0210 - val_loss: 0.0028
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0173 - val_loss: 0.0038
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0221 - val_loss: 0.0031
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0247 - val_loss: 0.0033
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0212 - val_loss: 0.0022
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0150 - val_loss: 0.0028
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0150 - val_loss: 0.0030
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0201 - val_loss: 0.0017
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0170 - val_loss: 0.0039
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0026
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0105 - val_loss: 0.0038
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0166 - val_loss: 0.0020
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0125 - val_loss: 0.0022
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0114 - val_loss: 0.0022
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0158 - val_loss: 0.0026
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0147 - val_loss: 0.0026
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0103 - val_loss: 0.0043
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0102 - val_loss: 0.0029
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0111 - val_loss: 0.0021
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0083 - val_loss: 0.0060
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0111 - val_loss: 0.0087
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0160 - val_loss: 0.0025
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0094 - val_loss: 0.0031
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0123 - val_loss: 0.0035
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0108 - val_loss: 0.0036
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0080 - val_loss: 0.0027
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0128 - val_loss: 0.0025
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0083 - val_loss: 0.0023
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0088 - val_loss: 0.0028
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0126 - val_loss: 0.0026
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0095 - val_loss: 0.0018
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0082 - val_loss: 0.0025
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0092 - val_loss: 0.0020
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0091 - val_loss: 0.0018
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0092 - val_loss: 0.0015
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0110 - val_loss: 0.0018
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0110 - val_loss: 0.0016
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0080 - val_loss: 0.0023
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0090 - val_loss: 0.0021
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0094 - val_loss: 0.0018
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0077 - val_loss: 0.0040
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0077 - val_loss: 0.0022
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0094 - val_loss: 0.0014
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0080 - val_loss: 0.0023
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0082 - val_loss: 0.0026
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0110 - val_loss: 0.0034
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0095 - val_loss: 0.0016
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0068 - val_loss: 0.0018
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0090 - val_loss: 0.0025
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0080 - val_loss: 0.0020
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0071 - val_loss: 0.0023
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0061 - val_loss: 0.0018
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0060 - val_loss: 0.0016
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0072 - val_loss: 0.0013
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0079 - val_loss: 0.0029
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0083 - val_loss: 0.0023
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0097 - val_loss: 0.0027
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0105 - val_loss: 0.0022
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0116 - val_loss: 0.0019
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0064 - val_loss: 0.0016
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0069 - val_loss: 0.0026
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0076 - val_loss: 0.0019
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0085 - val_loss: 0.0020
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0076 - val_loss: 0.0021
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0074 - val_loss: 0.0016
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0088 - val_loss: 0.0032
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0060 - val_loss: 0.0020
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0069 - val_loss: 0.0023
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0068 - val_loss: 0.0020
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0059 - val_loss: 0.0019
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0075 - val_loss: 0.0021
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0066 - val_loss: 0.0034
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0091 - val_loss: 0.0015
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0089 - val_loss: 0.0019
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0066 - val_loss: 0.0017
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0049 - val_loss: 0.0025
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0080 - val_loss: 0.0020

# %% [markdown]
# LSTM MODEL

# %%
# Define LSTM model
lstm_model = Sequential([
    LSTM(100, activation='tanh', return_sequences=True, input_shape=(seq_length, 1)),
    Dropout(0.3),
    LSTM(100, activation='tanh'),
    Dropout(0.3),
    Dense(1)
])
lstm_model.compile(optimizer=Adam(learning_rate=0.0005), loss='mse')  # Using MSE for LSTM model
lstm_history = lstm_model.fit(X_train, y_train, epochs=100, batch_size=4, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 0.1190 - val_loss: 0.0245
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0285 - val_loss: 0.0258
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0385 - val_loss: 0.0227
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0345 - val_loss: 0.0219
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0287 - val_loss: 0.0244
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0306 - val_loss: 0.0208
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0296 - val_loss: 0.0204
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0340 - val_loss: 0.0198
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0274 - val_loss: 0.0204
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0306 - val_loss: 0.0185
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0288 - val_loss: 0.0165
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0236 - val_loss: 0.0127
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0119 - val_loss: 0.0073
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0159 - val_loss: 0.0074
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0104 - val_loss: 0.0054
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0090 - val_loss: 0.0057
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0103 - val_loss: 0.0064
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0107 - val_loss: 0.0058
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0081 - val_loss: 0.0048
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0108 - val_loss: 0.0049
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0101 - val_loss: 0.0048
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0084 - val_loss: 0.0044
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0079 - val_loss: 0.0050
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0106 - val_loss: 0.0033
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0076 - val_loss: 0.0033
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0084 - val_loss: 0.0048
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0060 - val_loss: 0.0035
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0089 - val_loss: 0.0030
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0075 - val_loss: 0.0024
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0079 - val_loss: 0.0035
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0060 - val_loss: 0.0026
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0072 - val_loss: 0.0039
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0105 - val_loss: 0.0043
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0094 - val_loss: 0.0028
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0104 - val_loss: 0.0028
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0074 - val_loss: 0.0018
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0069 - val_loss: 0.0026
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0082 - val_loss: 0.0020
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0060 - val_loss: 0.0028
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0097 - val_loss: 0.0040
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0087 - val_loss: 0.0020
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0060 - val_loss: 0.0038
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0095 - val_loss: 0.0021
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0082 - val_loss: 0.0029
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0079 - val_loss: 0.0018
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0075 - val_loss: 0.0020
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0059 - val_loss: 0.0018
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0073 - val_loss: 0.0025
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0073 - val_loss: 0.0020
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0062 - val_loss: 0.0018
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0076 - val_loss: 0.0020
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0047 - val_loss: 0.0020
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0066 - val_loss: 0.0023
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0086 - val_loss: 0.0020
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0071 - val_loss: 0.0016
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0064 - val_loss: 0.0038
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0102 - val_loss: 0.0018
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0096 - val_loss: 0.0043
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0061 - val_loss: 0.0024
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0091 - val_loss: 0.0019
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0079 - val_loss: 0.0018
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0084 - val_loss: 0.0029
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0055 - val_loss: 0.0020
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0063 - val_loss: 0.0022
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0067 - val_loss: 0.0015
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0079 - val_loss: 0.0015
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0082 - val_loss: 0.0015
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0073 - val_loss: 0.0027
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0079 - val_loss: 0.0030
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0054 - val_loss: 0.0018
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0059 - val_loss: 0.0019
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0058 - val_loss: 0.0018
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0062 - val_loss: 0.0014
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0065 - val_loss: 0.0018
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0056 - val_loss: 0.0026
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0075 - val_loss: 0.0021
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0056 - val_loss: 0.0016
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0077 - val_loss: 0.0014
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0071 - val_loss: 0.0019
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0080 - val_loss: 0.0015
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0075 - val_loss: 0.0031
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0062 - val_loss: 0.0031
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0066 - val_loss: 0.0018
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0071 - val_loss: 0.0022
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0067 - val_loss: 0.0018
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0049 - val_loss: 0.0028
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0084 - val_loss: 0.0024
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0080 - val_loss: 0.0024
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0066 - val_loss: 0.0016

# %% [markdown]
# MODEL EVALUATION AND PREDICTION

# %%
rnn_predictions = rnn_model.predict(X_test)
lstm_predictions = lstm_model.predict(X_test)
rnn_predictions = scaler.inverse_transform(rnn_predictions) # Inverse transform predictions to original scale
lstm_predictions = scaler.inverse_transform(lstm_predictions)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 859ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = sqrt(mse)
    return mae, rmse

# %%
rnn_mae, rnn_rmse = evaluate_model(y_test, rnn_predictions)
print(f"RNN MAE: {rnn_mae}, RNN RMSE: {rnn_rmse}")
# Out:
# RNN MAE: 1242399.8, RNN RMSE: 1486466.1210350988

# %%
# Evaluate LSTM model
lstm_mae, lstm_rmse = evaluate_model(y_test, lstm_predictions)
print(f"LSTM MAE: {lstm_mae}, LSTM RMSE: {lstm_rmse}")
# Out:
# LSTM MAE: 1026806.6, LSTM RMSE: 1295297.98490965

# %%
plt.figure(figsize=(12, 5))
plt.plot(rnn_history.history['loss'], label='RNN Train Loss')
plt.plot(rnn_history.history['val_loss'], label='RNN Val Loss')
plt.plot(lstm_history.history['loss'], label='LSTM Train Loss')
plt.plot(lstm_history.history['val_loss'], label='LSTM Val Loss')
plt.legend()
plt.title("Loss Curves for RNN and LSTM")
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.show()

# %%
# Plot Predicted vs Actual for RNN and LSTM
plt.figure(figsize=(12, 6))

# Plot for RNN
plt.subplot(1, 2, 1)
plt.plot(y_test, label='Actual', color='blue')
plt.plot(rnn_predictions, label='Predicted (RNN)', color='orange')
plt.title('RNN: Actual vs Predicted')
plt.legend()

# Plot for LSTM
plt.subplot(1, 2, 2)
plt.plot(y_test, label='Actual', color='blue')
plt.plot(lstm_predictions, label='Predicted (LSTM)', color='green')
plt.title('LSTM: Actual vs Predicted')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# FUTURE FORECAST

# %%
def forecast_future(model, data, seq_length, n_forecasts):
    predictions = []
    input_seq = data[-seq_length:]  # Start with the last sequence of the training data

    
    for _ in range(n_forecasts):
        input_seq = input_seq.reshape((1, seq_length, 1))  # Reshape for model input
        next_value = model.predict(input_seq)
        predictions.append(next_value[0][0])  # Extract scalar value from prediction

        # Update the input sequence by appending the predicted value and removing the first element
        input_seq = np.append(input_seq[0][1:], next_value[0][0])  # Update sequence

    return np.array(predictions)

# %%
# Forecast the next 24 months
rnn_forecast = forecast_future(rnn_model, data['nd'].values, seq_length, 24)
lstm_forecast = forecast_future(lstm_model, data['nd'].values, seq_length, 24)

# Inverse transform the forecasts to original scale
rnn_forecast = scaler.inverse_transform(rnn_forecast.reshape(-1, 1))
lstm_forecast = scaler.inverse_transform(lstm_forecast.reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 862ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step

# %%
future_dates = pd.date_range(start=data['settlement_date'].iloc[-1], periods=25, freq='MS')[1:]

rnn_forecast_df = pd.DataFrame({
    'Date': future_dates,
    'Forecasted Demand (RNN)': rnn_forecast.flatten()
})

lstm_forecast_df = pd.DataFrame({
    'Date': future_dates,
    'Forecasted Demand (LSTM)': lstm_forecast.flatten()
})

# %%
rnn_forecast_df
# Out:
#          Date  Forecasted Demand (RNN)
# 0  2025-01-01              118330048.0
# 1  2025-02-01               76473472.0
# 2  2025-03-01               45292780.0
# 3  2025-04-01               33492816.0
# 4  2025-05-01               40326204.0
# 5  2025-06-01               40484320.0
# 6  2025-07-01               43546488.0
# 7  2025-08-01               39672996.0
# 8  2025-09-01               61415684.0
# 9  2025-10-01               48107728.0
# 10 2025-11-01               19526130.0
# 11 2025-12-01               37720100.0
# 12 2026-01-01               30711348.0
# 13 2026-02-01               60410784.0
# 14 2026-03-01               33497172.0
# 15 2026-04-01               29918188.0
# 16 2026-05-01               41401760.0
# 17 2026-06-01               33261230.0
# 18 2026-07-01               29230854.0
# 19 2026-08-01               24432784.0
# 20 2026-09-01               33955724.0
# 21 2026-10-01               42865504.0
# 22 2026-11-01               41275420.0
# 23 2026-12-01               63059960.0

# %%
lstm_forecast_df
# Out:
#          Date  Forecasted Demand (LSTM)
# 0  2025-01-01               114960168.0
# 1  2025-02-01               119237032.0
# 2  2025-03-01               112975320.0
# 3  2025-04-01               107074344.0
# 4  2025-05-01               101930944.0
# 5  2025-06-01                95814424.0
# 6  2025-07-01                87102056.0
# 7  2025-08-01                78711696.0
# 8  2025-09-01                72733808.0
# 9  2025-10-01                69260112.0
# 10 2025-11-01                67835240.0
# 11 2025-12-01                68047296.0
# 12 2026-01-01                69829888.0
# 13 2026-02-01                73467312.0
# 14 2026-03-01                79181112.0
# 15 2026-04-01                86300184.0
# 16 2026-05-01                92369032.0
# 17 2026-06-01                93983576.0
# 18 2026-07-01                89938992.0
# 19 2026-08-01                82642152.0
# 20 2026-09-01                75647368.0
# 21 2026-10-01                70976664.0
# 22 2026-11-01                69308488.0
# 23 2026-12-01                70954720.0

# %%
plt.figure(figsize=(12, 6))
plt.plot(rnn_forecast_df['Date'], rnn_forecast_df['Forecasted Demand (RNN)'], label='RNN Forecast', color='blue', linestyle='-', marker='o')
plt.plot(lstm_forecast_df['Date'], lstm_forecast_df['Forecasted Demand (LSTM)'], label='LSTM Forecast', color='green', linestyle='--', marker='x')
plt.title('RNN vs LSTM 24-Month Forecast')
plt.xlabel('Date')
plt.ylabel('Forecasted Demand')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# MODEL MERTRIC COMPARISON

# %%
data = {
    'Model': ['RNN', 'LSTM', 'ARIMA'],
    'MAE': [1083936.87, 1057001.13, 2967344.15],
    'RMSE': [1409467.74, 1349644.82, 3651363.45]
}

metrics_df = pd.DataFrame(data)

def highlight_best(val):
    color = 'lightgreen' if val == metrics_df[['MAE', 'RMSE']].min().min() else ''
    return f'background-color: {color}'

highlighted_df = metrics_df.style.applymap(highlight_best, subset=['MAE', 'RMSE'])
highlighted_df
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23820\243878645.py:13: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   highlighted_df = metrics_df.style.applymap(highlight_best, subset=['MAE', 'RMSE'])
# <style type="text/css">
# #T_7be83_row0_col1, #T_7be83_row0_col2, #T_7be83_row1_col2, #T_7be83_row2_col1, #T_7be83_row2_col2 {
#   background-color: ;
# }
# #T_7be83_row1_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7be83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7be83_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7be83_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7be83_level0_col2" class="col_heading level0 col2" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7be83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7be83_row0_col0" class="data row0 col0" >RNN</td>
#       <td id="T_7be83_row0_col1" class="data row0 col1" >1083936.870000</td>
#       <td id="T_7be83_row0_col2" class="data row0 col2" >1409467.740000</td>
#     </tr>
#     <tr>
#       <th id="T_7be83_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7be83_row1_col0" class="data row1 col0" >LSTM</td>
#       <td id="T_7be83_row1_col1" class="data row1 col1" >1057001.130000</td>
#       <td id="T_7be83_row1_col2" class="data row1 col2" >1349644.820000</td>
#     </tr>
#     <tr>
#       <th id="T_7be83_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7be83_row2_col0" class="data row2 col0" >ARIMA</td>
#       <td id="T_7be83_row2_col1" class="data row2 col1" >2967344.150000</td>
#       <td id="T_7be83_row2_col2" class="data row2 col2" >3651363.450000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !pip install scikeras[tensorflow]
# Out:
# Collecting scikeras[tensorflow]
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikeras[tensorflow]) (3.9.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\administrator\anaconda3\lib\site-packages (from scikeras[tensorflow]) (1.4.2)
# Requirement already satisfied: tensorflow>=2.16.1 in c:\users\administrator\anaconda3\lib\site-packages (from scikeras[tensorflow]) (2.19.0)
# Requirement already satisfied: absl-py in c:\users\administrator\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras[tensorflow]) (2.2.2)
# Requirement already satisfied: numpy in c:\users\administrator\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras[tensorflow]) (1.26.4)
# Requirement already satisfied: rich in c:\users\administrator\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras[tensorflow]) (13.3.5)
# Requirement already satisfied: namex in c:\users\administrator\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras[tensorflow]) (0.0.9)
# Requirement already satisfied: h5py in c:\users\administrator\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras[tensorflow]) (3.11.0)
# Requirement already satisfied: optree in c:\users\administrator\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras[tensorflow]) (0.15.0)
# Requirement already satisfied: ml-dtypes in c:\users\administrator\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras[tensorflow]) (0.5.1)
# Requirement already satisfied: packaging in c:\users\administrator\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras[tensorflow]) (23.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras[tensorflow]) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras[tensorflow]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras[tensorflow]) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.16.1->scikeras[tensorflow]) (2.19.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\administrator\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow>=2.16.1->scikeras[tensorflow]) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.1->scikeras[tensorflow]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.1->scikeras[tensorflow]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.1->scikeras[tensorflow]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.1->scikeras[tensorflow]) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=2.16.1->scikeras[tensorflow]) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=2.16.1->scikeras[tensorflow]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=2.16.1->scikeras[tensorflow]) (3.0.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\administrator\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras[tensorflow]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\administrator\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras[tensorflow]) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\administrator\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->scikeras[tensorflow]) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\administrator\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.16.1->scikeras[tensorflow]) (2.1.3)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0
